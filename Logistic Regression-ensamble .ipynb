# %%
import pandas as pd
import numpy as np

# %%
train_df=pd.read_csv('train_ctrUa4K.csv')
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
train_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df['Dependents'] = train_df['Dependents'].replace(to_replace = '3+', value = 4)

# %%
train_df['Gender'].fillna(train_df['Gender'].mode()[0],inplace=True)
train_df['Married'].fillna(train_df['Married'].mode()[0],inplace=True)
train_df['Dependents'].fillna(train_df['Dependents'].mode()[0],inplace=True)
train_df['Self_Employed'].fillna(train_df['Self_Employed'].mode()[0],inplace=True)

# %%
train_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df['Loan_Amount_Term'].fillna(train_df['Loan_Amount_Term'].mode()[0],inplace=True)
train_df['Credit_History'].fillna(train_df['Credit_History'].mode()[0],inplace=True)

# %%
train_df.isnull().sum()
# Out:
# Loan_ID               0
# Gender                0
# Married               0
# Dependents            0
# Education             0
# Self_Employed         0
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term      0
# Credit_History        0
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
train_df['LoanAmount'].fillna(train_df['LoanAmount'].mean(),inplace=True)

# %%
train_df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes          4      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %%
train_df.to_csv('train_df.csv',index=False)

# %%
train_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
train_df['Credit_History'].nunique()
# Out:
# 2

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

train_df['Gender']= label_encoder.fit_transform(train_df['Gender'])
train_df['Married']= label_encoder.fit_transform(train_df['Married'])
train_df['Education']= label_encoder.fit_transform(train_df['Education'])
train_df['Self_Employed']= label_encoder.fit_transform(train_df['Self_Employed'])
train_df['Property_Area']= label_encoder.fit_transform(train_df['Property_Area'])
train_df['Loan_Status']= label_encoder.fit_transform(train_df['Loan_Status'])
train_df['Credit_History']= label_encoder.fit_transform(train_df['Credit_History'])

# %%
train_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001002       1        0          0          0              0
# 1    LP001003       1        1          1          0              0
# 2    LP001005       1        1          0          0              1
# 3    LP001006       1        1          0          1              0
# 4    LP001008       1        0          0          0              0
# ..        ...     ...      ...        ...        ...            ...
# 609  LP002978       0        0          0          0              0
# 610  LP002979       1        1          4          0              0
# 611  LP002983       1        1          1          0              0
# 612  LP002984       1        1          2          0              0
# 613  LP002990       0        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5849                0.0  146.412162             360.0
# ...

# %%
train_df.drop("Loan_ID",axis=1,inplace=True)

# %%
train_df
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          0          0              0             5849
# 1         1        1          1          0              0             4583
# 2         1        1          0          0              1             3000
# 3         1        1          0          1              0             2583
# 4         1        0          0          0              0             6000
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          0              0             2900
# 610       1        1          4          0              0             4106
# 611       1        1          1          0              0             8072
# 612       1        1          2          0              0             7583
# 613       0        0          0          0              1             4583
#
# ...

# %%
test_df=pd.read_csv('test_lAUu6dG.csv')
test_df
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
test_df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
test_df['Dependents'] = test_df['Dependents'].replace(to_replace = '3+', value = 4)

# %%
test_df['Gender'] = test_df['Gender'].fillna(test_df['Gender'].mode()[0])
test_df['Married'] = test_df['Married'].fillna(test_df['Married'].mode()[0])
test_df['Dependents'] = test_df['Dependents'].fillna(test_df['Dependents'].mode()[0])
test_df['Self_Employed'] = test_df['Self_Employed'].fillna(test_df['Self_Employed'].mode()[0])
test_df['LoanAmount'] = test_df['LoanAmount'].fillna(test_df['LoanAmount'].mean())
test_df['Loan_Amount_Term'] = test_df['Loan_Amount_Term'].fillna(test_df['Loan_Amount_Term'].mean())
test_df['Credit_History'] = test_df['Credit_History'].fillna(test_df['Credit_History'].mode()[0])

# %%
test_df.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %%
from sklearn import preprocessing
  
label_encoder = preprocessing.LabelEncoder()

test_df['Gender']= label_encoder.fit_transform(test_df['Gender'])
test_df['Married']= label_encoder.fit_transform(test_df['Married'])
test_df['Education']= label_encoder.fit_transform(test_df['Education'])
test_df['Self_Employed']= label_encoder.fit_transform(test_df['Self_Employed'])
test_df['Property_Area']= label_encoder.fit_transform(test_df['Property_Area'])

# %%
test = test_df.iloc[:,1:]
test
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        1          0          0              0             5720
# 1         1        1          1          0              0             3076
# 2         1        1          2          0              0             5000
# 3         1        1          2          0              0             2340
# 4         1        0          0          1              0             3276
# ..      ...      ...        ...        ...            ...              ...
# 362       1        1          4          1              1             4009
# 363       1        1          0          0              0             4158
# 364       1        0          0          0              0             3250
# 365       1        1          0          0              0             5000
# 366       1        0          0          0              1             9200
#
# ...

# %%
X_train = train_df.iloc[:,:11]
X_train
# Out:
#      Gender  Married Dependents  Education  Self_Employed  ApplicantIncome  \
# 0         1        0          0          0              0             5849
# 1         1        1          1          0              0             4583
# 2         1        1          0          0              1             3000
# 3         1        1          0          1              0             2583
# 4         1        0          0          0              0             6000
# ..      ...      ...        ...        ...            ...              ...
# 609       0        0          0          0              0             2900
# 610       1        1          4          0              0             4106
# 611       1        1          1          0              0             8072
# 612       1        1          2          0              0             7583
# 613       0        0          0          0              1             4583
#
# ...

# %%
y_train = train_df.Loan_Status
y_train
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int32

# %%
test_df
# Out:
#       Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0    LP001015       1        1          0          0              0
# 1    LP001022       1        1          1          0              0
# 2    LP001031       1        1          2          0              0
# 3    LP001035       1        1          2          0              0
# 4    LP001051       1        0          0          1              0
# ..        ...     ...      ...        ...        ...            ...
# 362  LP002971       1        1          4          1              1
# 363  LP002975       1        1          0          0              0
# 364  LP002980       1        0          0          0              0
# 365  LP002986       1        1          0          0              0
# 366  LP002989       1        0          0          0              1
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %%
from sklearn.preprocessing import StandardScaler
s1=StandardScaler()
X_train=s1.fit_transform(X_train)
test=s1.fit_transform(test)

# %%
ab=X_train.mean()
ab=round(ab)
ab
# Out:
# 0

# %%
ab1=X_train.var()
ab1=round(ab1)
ab1
# Out:
# 1

# %%
from sklearn.linear_model import LogisticRegression
l1=LogisticRegression()
l1.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = l1.predict(test)

# %%
y_pred.shape
# Out:
# (367,)

# %%
submission=test_df.iloc[:,0:1]
submission
# Out:
#       Loan_ID
# 0    LP001015
# 1    LP001022
# 2    LP001031
# 3    LP001035
# 4    LP001051
# ..        ...
# 362  LP002971
# 363  LP002975
# 364  LP002980
# 365  LP002986
# 366  LP002989
#
# [367 rows x 1 columns]

# %%
submission['Loan_Status']=y_pred
submission
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8480\3208576047.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['Loan_Status']=y_pred
#       Loan_ID  Loan_Status
# 0    LP001015            1
# 1    LP001022            1
# 2    LP001031            1
# 3    LP001035            1
# 4    LP001051            1
# ..        ...          ...
# 362  LP002971            1
# 363  LP002975            1
# 364  LP002980            1
# 365  LP002986            1
# 366  LP002989            1
#
# [367 rows x 2 columns]

# %%
submission['Loan_Status'] = submission['Loan_Status'].replace({0: 'N', 1: 'Y'})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8480\1826290913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['Loan_Status'] = submission['Loan_Status'].replace({0: 'N', 1: 'Y'})

# %%
submission
# Out:
#       Loan_ID Loan_Status
# 0    LP001015           Y
# 1    LP001022           Y
# 2    LP001031           Y
# 3    LP001035           Y
# 4    LP001051           Y
# ..        ...         ...
# 362  LP002971           Y
# 363  LP002975           Y
# 364  LP002980           Y
# 365  LP002986           Y
# 366  LP002989           Y
#
# [367 rows x 2 columns]

# %%
submission.to_csv('submission_0.3.csv',index=False)

# %%
train_df['Loan_Status'].value_counts()
# Out:
# 1    422
# 0    192
# Name: Loan_Status, dtype: int64

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x_data,y_data=sm.fit_resample(X_train,y_train)

# %%
from sklearn.linear_model import LogisticRegression
l1=LogisticRegression()
l1.fit(x_data,y_data)
# Out:
# LogisticRegression()

# %%
final_pred = l1.predict(test)

# %%
final_pred.shape
# Out:
# (367,)

# %%
submission=test_df.iloc[:,0:1]
submission
# Out:
#       Loan_ID
# 0    LP001015
# 1    LP001022
# 2    LP001031
# 3    LP001035
# 4    LP001051
# ..        ...
# 362  LP002971
# 363  LP002975
# 364  LP002980
# 365  LP002986
# 366  LP002989
#
# [367 rows x 1 columns]

# %%
submission['Loan_Status']=final_pred
submission
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8480\2598316575.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['Loan_Status']=final_pred
#       Loan_ID  Loan_Status
# 0    LP001015            1
# 1    LP001022            1
# 2    LP001031            1
# 3    LP001035            1
# 4    LP001051            1
# ..        ...          ...
# 362  LP002971            1
# 363  LP002975            1
# 364  LP002980            1
# 365  LP002986            1
# 366  LP002989            1
#
# [367 rows x 2 columns]

# %%
submission['Loan_Status'] = submission['Loan_Status'].replace({0: 'N', 1: 'Y'})
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_8480\1826290913.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   submission['Loan_Status'] = submission['Loan_Status'].replace({0: 'N', 1: 'Y'})

# %%
submission
# Out:
#       Loan_ID Loan_Status
# 0    LP001015           Y
# 1    LP001022           Y
# 2    LP001031           Y
# 3    LP001035           Y
# 4    LP001051           Y
# ..        ...         ...
# 362  LP002971           Y
# 363  LP002975           Y
# 364  LP002980           Y
# 365  LP002986           Y
# 366  LP002989           Y
#
# [367 rows x 2 columns]

# %%
submission.to_csv('submission_0.4.csv',index=False)
